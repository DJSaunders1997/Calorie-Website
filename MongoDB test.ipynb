# %% [markdown]
# # Mongo DB
#
# This notebook will contain tests of me trying to use mongodb for the first time
#
# Start off following this tutorial: https://www.mongodb.com/blog/post/getting-started-with-python-and-mongodb

# %%
from pymongo import MongoClient
# pprint library is used to make the output look more pretty
from pprint import pprint

# %%
# Get password from local file not published to GitHub
f = open("password.txt", "r")
password = f.read()

# %%
# connect to MongoDB, change the << MONGODB URL >> to reflect your own connection string
client = MongoClient(f'mongodb+srv://user:{password}@cluster0.ad9pz.mongodb.net/test')
db=client.admin
# Issue the serverStatus command and print the results
serverStatusResult=db.command("serverStatus")
pprint(serverStatusResult)
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1619084204, 4),
#                   'signature': {'hash': b'D\xcbx\x99l\x18\xc6\xc6"%^\xc0'
#                                         b'\xb8\x9c\xaeM\xe0\x1d\xe6I',
#                                 'keyId': 6947050601314254850}},
#  'asserts': {'msg': 0, 'regular': 0, 'rollovers': 0, 'user': 0, 'warning': 0},
#  'atlasVersion': {'gitVersion': '8f7e5bdde713391e8123a463895bb7fb660a5ffd',
#                   'version': '20210330.0.0.1617063608'},
#  'connections': {'available': 473, 'current': 27, 'totalCreated': 74},
#  'extra_info': {'note': 'fields vary by platform', 'page_faults': 0},
#  'host': 'cluster0-shard-00-02.ad9pz.mongodb.net:27017',
#  'localTime': datetime.datetime(2021, 4, 22, 9, 36, 44, 602000),
#  'mem': {'bits': 64,
#          'mapped': 0,
#          'mappedWithJournal': 0,
#          'resident': 0,
#          'supported': True,
#          'virtual': 0},
#  'metrics': {'atlas': {'bytesInWrites': 960,
#                        'connectionPool': {'totalCreated': 23821}}},
#  'network': {'bytesIn': 1054903, 'bytesOut': 16955180, 'numRequests': 6341},
#  'ok': 1.0,
#  'opcounters': {'command': 5308,
#                 'delete': 0,
#                 'getmore': 0,
#                 'insert': 1001,
#                 'query': 22,
#                 'update': 3},
#  'opcountersRepl': {'command': 0,
#                     'delete': 0,
#                     'getmore': 0,
#                     'insert': 0,
#                     'query': 0,
#                     'update': 0},
#  'operationTime': Timestamp(1619084204, 4),
#  'pid': 8524,
#  'process': 'mongod',
#  'repl': {'electionId': ObjectId('7fffffff0000000000000004'),
#           'hosts': ['cluster0-shard-00-00.ad9pz.mongodb.net:27017',
#                     'cluster0-shard-00-01.ad9pz.mongodb.net:27017',
#                     'cluster0-shard-00-02.ad9pz.mongodb.net:27017'],
#           'ismaster': True,
#           'lastWrite': {'lastWriteDate': datetime.datetime(2021, 4, 22, 9, 36, 44),
#                         'majorityOpTime': {'t': 4,
#                                            'ts': Timestamp(1619084204, 4)},
#                         'majorityWriteDate': datetime.datetime(2021, 4, 22, 9, 36, 44),
#                         'opTime': {'t': 4, 'ts': Timestamp(1619084204, 4)}},
#           'me': 'cluster0-shard-00-02.ad9pz.mongodb.net:27017',
#           'primary': 'cluster0-shard-00-02.ad9pz.mongodb.net:27017',
#           'rbid': 1,
#           'secondary': False,
#           'setName': 'atlas-8slsw4-shard-0',
#           'setVersion': 1,
#           'tags': {'nodeType': 'ELECTABLE',
#                    'provider': 'AZURE',
#                    'region': 'EUROPE_WEST',
#                    'workloadType': 'OPERATIONAL'},
#           'topologyVersion': {'counter': 6,
#                               'processId': ObjectId('607b17024938e84eeeaed655')}},
#  'storageEngine': {'backupCursorOpen': False,
#                    'dropPendingIdents': 0,
#                    'name': 'wiredTiger',
#                    'oldestRequiredTimestampForCrashRecovery': Timestamp(1619084194, 4),
#                    'persistent': True,
#                    'readOnly': False,
#                    'supportsCommittedReads': True,
#                    'supportsPendingDrops': True,
#                    'supportsSnapshotReadConcern': True,
#                    'supportsTwoPhaseIndexBuild': True},
#  'throttledOps': 0,
#  'uptime': 404650.0,
#  'uptimeEstimate': 404649,
#  'uptimeMillis': 404649777,
#  'version': '4.4.5'}

# %%
# Create new database
db = client.business

# %%
# createsamples.py

from pymongo import MongoClient
from random import randint
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient(f'mongodb+srv://user:{password}@cluster0.ad9pz.mongodb.net/test')
db=client.business
#Step 2: Create sample data
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']
for x in range(1, 501):
    business = {
        'name' : names[randint(0, (len(names)-1))] + ' ' + names[randint(0, (len(names)-1))]  + ' ' + company_type[randint(0, (len(company_type)-1))],
        'rating' : randint(1, 5),
        'cuisine' : company_cuisine[randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via isnert_one
    result=db.reviews.insert_one(business)
    #Step 4: Print to the console the ObjectID of the new document
    print('Created {0} of 500 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
# Out:
# 3053e67b7
# Created 76 of 500 as 60813e8e8dd3eb93053e67b8
# Created 77 of 500 as 60813e8e8dd3eb93053e67b9
# Created 78 of 500 as 60813e8e8dd3eb93053e67ba
# Created 79 of 500 as 60813e8e8dd3eb93053e67bb
# Created 80 of 500 as 60813e8e8dd3eb93053e67bc
# Created 81 of 500 as 60813e8e8dd3eb93053e67bd
# Created 82 of 500 as 60813e8e8dd3eb93053e67be
# Created 83 of 500 as 60813e8e8dd3eb93053e67bf
# Created 84 of 500 as 60813e8e8dd3eb93053e67c0
# Created 85 of 500 as 60813e8f8dd3eb93053e67c1
# Created 86 of 500 as 60813e8f8dd3eb93053e67c2
# Created 87 of 500 as 60813e8f8dd3eb93053e67c3
# Created 88 of 500 as 60813e8f8dd3eb93053e67c4
# Created 89 of 500 as 60813e8f8dd3eb93053e67c5
# Created 90 of 500 as 60813e8f8dd3eb93053e67c6
# Created 91 of 500 as 60813e8f8dd3eb93053e67c7
# Created 92 of 500 as 60813e8f8dd3eb93053e67c8
# Created 93 of 500 as 60813e8f8dd3eb93053e67c9
# Created 94 of 500 as 60813e8f8dd3eb93053e67ca
# Created 95 of 500 as 60813e8f8dd3eb93053e67cb
# Created 96 of 500 as 60813e8f8dd3eb93053e67cc
# Created 97 of 500 as 60813e8f8dd3eb93053e67cd
# Created 98 of 500 as 60813e8f8dd3eb93053e67ce
# Created 99 of 500 as 60813e8f8dd3eb93053e67cf
# Created 100 of 500 as 60813e8f8dd3eb93053e67d0
# Created 101 of 500 as 60813e8f8dd3eb93053e67d1
# Created 102 of 500 as 60813e8f8dd3eb93053e67d2
# Created 103 of 500 as 60813e8f8dd3eb93053e67d3
# Created 104 of 500 as 60813e8f8dd3eb93053e67d4
# Created 105 of 500 as 60813e8f8dd3eb93053e67d5
# Created 106 of 500 as 60813e8f8dd3eb93053e67d6
# Created 107 of 500 as 60813e8f8dd3eb93053e67d7
# Created 108 of 500 as 60813e8f8dd3eb93053e67d8
# Created 109 of 500 as 60813e8f8dd3eb93053e67d9
# Created 110 of 500 as 60813e8f8dd3eb93053e67da
# Created 165 of 500 as 60813e918dd3eb93053e6811
# Created 166 of 500 as 60813e918dd3eb93053e6812
# Created 167 of 500 as 60813e918dd3eb93053e6813
# Created 168 of 500 as 60813e918dd3eb93053e6814
# Created 169 of 500 as 60813e918dd3eb93053e6815
# Created 170 of 500 as 60813e918dd3eb93053e6816
# Created 171 of 500 as 60813e918dd3eb93053e6817
# Created 172 of 500 as 60813e918dd3eb93053e6818
# Created 173 of 500 as 60813e918dd3eb93053e6819
# Created 174 of 500 as 60813e918dd3eb93053e681a
# Created 175 of 500 as 60813e918dd3eb93053e681b
# Created 176 of 500 as 60813e918dd3eb93053e681c
# Created 177 of 500 as 60813e918dd3eb93053e681d
# Created 178 of 500 as 60813e918dd3eb93053e681e
# Created 179 of 500 as 60813e918dd3eb93053e681f
# Created 180 of 500 as 60813e928dd3eb93053e6820
# Created 181 of 500 as 60813e928dd3eb93053e6821
# Created 182 of 500 as 60813e928dd3eb93053e6822
# Created 183 of 500 as 60813e928dd3eb93053e6823
# Created 184 of 500 as 60813e928dd3eb93053e6824
# Created 185 of 500 as 60813e928dd3eb93053e6825
# Created 186 of 500 as 60813e928dd3eb93053e6826
# Created 187 of 500 as 60813e928dd3eb93053e6827
# Created 188 of 500 as 60813e928dd3eb93053e6828
# Created 189 of 500 as 60813e928dd3eb93053e6829
# Created 190 of 500 as 60813e928dd3eb93053e682a
# Created 191 of 500 as 60813e928dd3eb93053e682b
# Created 192 of 500 as 60813e928dd3eb93053e682c
# Created 193 of 500 as 60813e928dd3eb93053e682d
# Created 194 of 500 as 60813e928dd3eb93053e682e
# Created 195 of 500 as 60813e928dd3eb93053e682f
# Created 196 of 500 as 60813e928dd3eb93053e6830
# Created 197 of 500 as 60813e928dd3eb93053e6831
# Created 198 of 500 as 60813e928dd3eb93053e6832
# Created 199 of 500 as 60813e928dd3eb93053e6833
# Created 200 of 500 as 60813e928dd3eb93053e6834
# Created 201 of 500 as 60813e928dd3eb93053e6835
# Created 202 of 500 as 60813e928dd3eb93053e6836
# Created 203 of 500 as 60813e928dd3eb93053e6837
# Created 204 of 500 as 60813e928dd3eb93053e6838
# Created 205 of 500 as 60813e928dd3eb93053e6839
# Created 206 of 500 as 60813e928dd3eb93053e683a
# Created 207 of 500 as 60813e928dd3eb93053e683b
# Created 208 of 500 as 60813e928dd3eb93053e683c
# Created 209 of 500 as 60813e928dd3eb93053e683d
# Created 210 of 500 as 60813e928dd3eb93053e683e
# Created 211 of 500 as 60813e928dd3eb93053e683f
# Created 212 of 500 as 60813e928dd3eb93053e6840
# Created 213 of 500 as 60813e938dd3eb93053e6841
# Created 214 of 500 as 60813e938dd3eb93053e6842
# Created 215 of 500 as 60813e938dd3eb93053e6843
# Created 216 of 500 as 60813e938dd3eb93053e6844
# Created 217 of 500 as 60813e938dd3eb93053e6845
# Created 218 of 500 as 60813e938dd3eb93053e6846
# Created 481 of 500 as 60813ea58dd3eb93053e694d
# Created 482 of 500 as 60813ea58dd3eb93053e694e
# Created 483 of 500 as 60813ea58dd3eb93053e694f
# Created 484 of 500 as 60813ea58dd3eb93053e6950
# Created 485 of 500 as 60813ea58dd3eb93053e6951
# Created 486 of 500 as 60813ea58dd3eb93053e6952
# Created 487 of 500 as 60813ea58dd3eb93053e6953
# Created 488 of 500 as 60813ea58dd3eb93053e6954
# Created 489 of 500 as 60813ea58dd3eb93053e6955
# Created 490 of 500 as 60813ea58dd3eb93053e6956
# Created 491 of 500 as 60813ea58dd3eb93053e6957
# Created 492 of 500 as 60813ea58dd3eb93053e6958
# Created 493 of 500 as 60813ea58dd3eb93053e6959
# Created 494 of 500 as 60813ea58dd3eb93053e695a
# Created 495 of 500 as 60813ea58dd3eb93053e695b
# Created 496 of 500 as 60813ea58dd3eb93053e695c
# Created 497 of 500 as 60813ea68dd3eb93053e695d
# Created 498 of 500 as 60813ea68dd3eb93053e695e
# Created 499 of 500 as 60813ea68dd3eb93053e695f
# Created 500 of 500 as 60813ea68dd3eb93053e6960
# finished creating 500 business reviews

# %%
# Query Buisness DATABASE

fivestar = db.reviews.find_one({'rating': 5})
print(fivestar)

# # The result will contain data similar to the following:

# {u'rating': 5,
#  u'_id': ObjectId('58e65383ea0b650c867ef195'),
#  u'name': u'Fish Salty Corporation', 
# u'cuisine': u'Sushi Bar'}
fivestar['name']
# Out:
# {'_id': ObjectId('6080236236e575131fc7b598'), 'name': 'Sandwich Sandwich Inc', 'rating': 5, 'cuisine': 'Vegetarian', 'likes': 2}
# 'Sandwich Sandwich Inc'

# %%
# Get count of all buisnesses with 5 star reviews

fivestarcount = db.reviews.find({'rating': 5}).count()
print(fivestarcount)
# Out:
# 197
# <ipython-input-6-a113db52eaca>:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   fivestarcount = db.reviews.find({'rating': 5}).count()

# %%
# Run multiple queries at once with MongoDB aggregation pipelines

from pymongo import MongoClient
# Connect to the MongoDB, change the connection string per your MongoDB environment
# client = MongoClient(port=27017) # Dave: Client has been specified earlier so comment out line
# Set the db object to point to the business database
db=client.business
# Showcasing the count() method of find, count the total number of 5 ratings 
print('The number of 5 star reviews:')
fivestarcount = db.reviews.find({'rating': 5}).count()
print(fivestarcount)
# Now let's use the aggregation framework to sum the occurrence of each rating across the entire data set
print('\nThe sum of each rating occurance across all data grouped by rating ')
stargroup=db.reviews.aggregate(
# The Aggregation Pipeline is defined as an array of different operations
[
# The first stage in this pipe is to group data
{ '$group':
    { '_id': "$rating",
     "count" : 
                 { '$sum' :1 }
    }
},
# The second stage in this pipe is to sort the data
{"$sort":  { "_id":1}
}
# Close the array with the ] tag             
] )
# Print the result
for group in stargroup:
    print(group)
# Out:
# The number of 5 star reviews:
# 197
#
# The sum of each rating occurance across all data grouped by rating
# {'_id': 1, 'count': 199}
# {'_id': 2, 'count': 198}
# {'_id': 3, 'count': 197}
# {'_id': 4, 'count': 209}
# {'_id': 5, 'count': 197}
# <ipython-input-7-9b1ba9e2e31b>:10: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   fivestarcount = db.reviews.find({'rating': 5}).count()

# %%
# Updating data

from pymongo import MongoClient
#include pprint for readabillity of the 
from pprint import pprint

#change the MongoClient connection string to your MongoDB database instance
#client = MongoClient(port=27020)
db=client.business

ASingleReview = db.reviews.find_one({})
print('A sample document:')
pprint(ASingleReview)

result = db.reviews.update_one({'_id' : ASingleReview.get('_id') }, {'$inc': {'likes': 1}})
print('Number of documents modified : ' + str(result.modified_count))

UpdatedDocument = db.reviews.find_one({'_id':ASingleReview.get('_id')})
print('The updated document:')
pprint(UpdatedDocument)
# Out:
# A sample document:
# {'_id': ObjectId('6080236236e575131fc7b598'),
#  'cuisine': 'Vegetarian',
#  'likes': 2,
#  'name': 'Sandwich Sandwich Inc',
#  'rating': 5}
# Number of documents modified : 1
# The updated document:
# {'_id': ObjectId('6080236236e575131fc7b598'),
#  'cuisine': 'Vegetarian',
#  'likes': 3,
#  'name': 'Sandwich Sandwich Inc',
#  'rating': 5}

# %%
# Now read this to learn more and design database "schema" https://www.tutorialspoint.com/mongodb/mongodb_data_modeling.htm

# %%
"_id": "fdhjfdshh",
"person":"Dave",
"target": 2000,
"calories": {
    "2021-04-18": 1800,
    "2021-04-19": 2300,
    "2021-04-20": 1750,
    "2021-04-21": 1890
}

OR

"_id": "fdhjfdshh",
"person":"Dave",
"target": 2000,
"calories": {
    "2021-04-18 09:00": 300,
    "2021-04-18 13:00": 200,
    "2021-04-18 17:00": 650,
    "2021-04-18 21:00": 300,
    "2021-04-19 13:00": 650,
    "2021-04-19 19:00": 300,
}
# Out:
#   File "<ipython-input-10-9d01cceabcfb>", line 1
#     "_id": "fdhjfdshh",
#                       ^
# SyntaxError: invalid syntax

# %%
design_1 = {
    "_id": "fdhjfdshh",
    "person":"Dave",
    "target": 2000,
    "calories": [
        {"timestamp": "2021-04-18 09:00", "calories": 200},
        {"timestamp": "2021-04-18 14:00", "calories": 700},
        {"timestamp": "2021-04-18 21:00", "calories": 1200},
        {"timestamp": "2021-04-19 09:30", "calories": 400},
        {"timestamp": "2021-04-18 12:00", "calories": 1200}
    ]
}

print(type(design_1))
design_1
# Out:
# <class 'dict'>
# {'_id': 'fdhjfdshh',
#  'person': 'Dave',
#  'target': 2000,
#  'calories': [{'timestamp': '2021-04-18 09:00', 'calories': 200},
#   {'timestamp': '2021-04-18 14:00', 'calories': 700},
#   {'timestamp': '2021-04-18 21:00', 'calories': 1200},
#   {'timestamp': '2021-04-19 09:30', 'calories': 400},
#   {'timestamp': '2021-04-18 12:00', 'calories': 1200}]}

# %%
design_2 = {
    "person1":{
        "name":"Dave",
        "target": 2000,
        "calories": [
            {"timestamp": "2021-04-18 09:00", "calories": 200},
            {"timestamp": "2021-04-18 14:00", "calories": 700},
            {"timestamp": "2021-04-18 21:00", "calories": 1200},
            {"timestamp": "2021-04-19 09:30", "calories": 400},
            {"timestamp": "2021-04-18 12:00", "calories": 1200}
        ]
    },
    "person2":{
        "name":"Meg",
        "target": 1800,
        "calories": [
            {"timestamp": "2021-04-18 08:00", "calories": 500},
            {"timestamp": "2021-04-18 16:00", "calories": 700},
            {"timestamp": "2021-04-18 23:00", "calories": 1700},
            {"timestamp": "2021-04-19 10:30", "calories": 100},
            {"timestamp": "2021-04-18 18:00", "calories": 100}
        ]
    }
}

print(type(design_2))
design_2
# Out:
# <class 'dict'>
# {'person1': {'id': 'gdfgf34',
#   'name': 'Dave',
#   'target': 2000,
#   'calories': [{'timestamp': '2021-04-18 09:s00', 'calories': 200},
#    {'timestamp': '2021-04-18 14:00', 'calories': 700},
#    {'timestamp': '2021-04-18 21:00', 'calories': 1200},
#    {'timestamp': '2021-04-19 09:30', 'calories': 400},
#    {'timestamp': '2021-04-18 12:00', 'calories': 1200}]},
#  'person2': {'is': 'jrtgh78',
#   'name': 'Meg',
#   'target': 1800,
#   'calories': [{'timestamp': '2021-04-18 08:00', 'calories': 500},
#    {'timestamp': '2021-04-18 16:00', 'calories': 700},
#    {'timestamp': '2021-04-18 23:00', 'calories': 1700},
#    {'timestamp': '2021-04-19 10:30', 'calories': 100},
#    {'timestamp': '2021-04-18 18:00', 'calories': 100}]}}

# %%
len(design_2)
# Out:
# 2

# %%
design_2["person2"]
# Out:
# {'is': 'jrtgh78',
#  'name': 'Meg',
#  'target': 1800,
#  'calories': [{'timestamp': '2021-04-18 08:00', 'calories': 500},
#   {'timestamp': '2021-04-18 16:00', 'calories': 700},
#   {'timestamp': '2021-04-18 23:00', 'calories': 1700},
#   {'timestamp': '2021-04-19 10:30', 'calories': 100},
#   {'timestamp': '2021-04-18 18:00', 'calories': 100}]}

# %%
import json

json_2 = json.dumps(design_2, indent=4)

# %%
print(json_2)
# Out:
# {
#     "person1": {
#         "id": "gdfgf34",
#         "name": "Dave",
#         "target": 2000,
#         "calories": [
#             {
#                 "timestamp": "2021-04-18 09:s00",
#                 "calories": 200
#             },
#             {
#                 "timestamp": "2021-04-18 14:00",
#                 "calories": 700
#             },
#             {
#                 "timestamp": "2021-04-18 21:00",
#                 "calories": 1200
#             },
#             {
#                 "timestamp": "2021-04-19 09:30",
#                 "calories": 400
#             },
#             {
#                 "timestamp": "2021-04-18 12:00",
#                 "calories": 1200
#             }
#         ]
#     },
#     "person2": {
#         "is": "jrtgh78",
#         "name": "Meg",
#         "target": 1800,
#         "calories": [
#             {
#                 "timestamp": "2021-04-18 08:00",
#                 "calories": 500
#             },
#             {
#                 "timestamp": "2021-04-18 16:00",
#                 "calories": 700
#             },
#             {
#                 "timestamp": "2021-04-18 23:00",
#                 "calories": 1700
#             },
#             {
#                 "timestamp": "2021-04-19 10:30",
#                 "calories": 100
#             },
#             {
#                 "timestamp": "2021-04-18 18:00",
#                 "calories": 100
#             }
#         ]
#     }
# }
